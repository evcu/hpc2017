# %% [markdown]
# # Read results and report

# %%
from collections import defaultdict
d=defaultdict(list)
with open('resultsGS.out','rb') as f:
    print f.next()
    for l in f:
        nthread,N = map(int,l.split())
        time = float(f.next().split()[3])
        d[nthread].append((N,time))
print d
# Out:
# Thu Mar 23 15:23:36 EDT 2017
#
# defaultdict(<type 'list'>, {32: [(100, 0.829039), (500, 1.519741), (1000, 3.646214), (2500, 20.946427), (5000, 85.467407)], 1: [(100, 0.192133), (500, 1.980587), (1000, 6.49405), (2500, 46.955482), (5000, 181.663764)], 4: [(100, 0.073208), (500, 0.983156), (1000, 1.627573), (2500, 22.226385), (5000, 82.60221)], 8: [(100, 0.025917), (500, 0.258832), (1000, 0.879714), (2500, 19.077342), (5000, 72.106561)], 64: [(100, 1.459554), (500, 1.73929), (1000, 4.760189), (2500, 20.815396), (5000, 78.233202)], 16: [(100, 111.010063), (500, 59.985972), (1000, 111.031107), (2500, 31.324037), (5000, 100.635983)], 24: [(100, 0.34463), (500, 1.330672), (1000, 2.797184), (2500, 20.546156), (5000, 81.010999)]})

# %%
import matplotlib.pyplot as plt

for k,v in d.items():
    x = [vv[0] for vv in v]
    y = [vv[1] for vv in v]
    plt.plot(x, y,label=k)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.ylabel("Time in seconds")
plt.xlabel("N")
plt.title("Time spent for 5000 iterations for Jacobi smoothing")
plt.savefig("JacobiAll.jpg")
plt.show()
